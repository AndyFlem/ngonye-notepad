# %%
import numpy as np
import pandas as pd
import datetime
import math

# %%
daily=pd.read_csv('dam_daily.csv')
daily
# Out:
#       year  month  day  volume       value  price_weight_av  price_mean  \
# 0     2016      1    1  7873.8  336882.508        42.785251   45.982500
# 1     2016      1    2  7319.5  345982.021        47.268532   54.114167
# 2     2016      1    3  7198.7  351712.733        48.857812   54.959167
# 3     2016      1    4  4457.0  225938.810        50.693024   80.164583
# 4     2016      1    5  3750.4  179068.882        47.746609   84.503333
# ...    ...    ...  ...     ...         ...              ...         ...
# 1942  2021      4   26  2092.9  185605.239        88.683281  102.215000
# 1943  2021      4   27  2048.2  168261.497        82.150912   94.468333
# 1944  2021      4   28  2130.2  177543.993        83.346161  100.343333
# 1945  2021      4   29  2134.0  178697.984        83.738512   98.742500
# 1946  2021      4   30  2198.9  187057.475        85.068659   98.218750
#
#       off_price_mean  standard_price_mean  morning_price_mean  \
# 0          45.982500                  NaN                 NaN
# 1          45.511333            68.452222                 NaN
# 2          48.152222            75.380000                 NaN
# 3          47.992222            80.720833                 NaN
# 4          43.756667            93.589167             148.400
# ...              ...                  ...                 ...
# 1942       42.868889            96.981818             201.055
# 1943       42.197778            80.660000             201.015
# 1944       42.605556            95.224545             189.575
# 1945       42.532222            92.590909             187.460
# 1946       42.047778            92.895455             182.510
#
#       evening_price_mean  off_hour_count  standard_hour_count  \
# 0                    NaN              24                  NaN
# 1                    NaN              15                  9.0
# 2                    NaN              18                  6.0
# 3             174.456667               9                 12.0
# 4             181.400000               9                 12.0
# ...                  ...             ...                  ...
# 1942          299.215000               9                 11.0
# 1943          299.085000               9                 11.0
# 1944          299.085000               9                 11.0
# 1945          296.805000               9                 11.0
# 1946          295.975000               9                 11.0
#
#       morning_hour_count  evening_hour_count  off_volume  standard_volume  \
# 0                    NaN                 NaN      7873.8              NaN
# 1                    NaN                 NaN      5994.5           1325.0
# 2                    NaN                 NaN      6607.3            591.4
# 3                    NaN                 3.0      4028.0            429.0
# 4                    1.0                 2.0      3380.0            370.4
# ...                  ...                 ...         ...              ...
# 1942                 2.0                 2.0       789.4           1065.1
# 1943                 2.0                 2.0       947.8            856.0
# 1944                 2.0                 2.0      1095.8            788.4
# 1945                 2.0                 2.0      1100.0            772.0
# 1946                 2.0                 2.0       912.7           1022.2
#
#       morning_volume  evening_volume
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             0.0
# 4                0.0             0.0
# ...              ...             ...
# 1942           144.3            94.1
# 1943           134.7           109.7
# 1944           136.0           110.0
# 1945           142.0           120.0
# 1946           144.0           120.0
#
# [1947 rows x 19 columns]

# %%
monthly=daily.groupby(['year','month']).mean().reset_index(['month','year'])
monthly=monthly.drop(['morning_volume','off_volume','standard_volume'],1)
monthly.rename(columns={'value':'value_mean','volume':'volume_mean','price_weight_av': 'price_weight_mean','off_hour_count':'off_hour_mean','standard_hour_count':'standard_hour_mean','morning_hour_count':'morning_hour_mean','evening_hour_count':'evening_hour_mean'}, inplace=True)
monthly[['price_max','standard_price_max','off_price_max','morning_price_max','evening_price_max']]=daily.groupby(['year','month']).max().reset_index(['month','year'])[['price_mean','standard_price_mean','off_price_mean','morning_price_mean','evening_price_mean']]
monthly[['price_min','standard_price_min','off_price_min','morning_price_min','evening_price_min']]=daily.groupby(['year','month']).min().reset_index(['month','year'])[['price_mean','standard_price_mean','off_price_mean','morning_price_mean','evening_price_mean']]
monthly[['off_price_stdev','morning_price_stdev','standard_price_stdev','evening_price_stdev']]=daily.groupby(['year','month']).std().reset_index(['month','year'])[['off_price_mean','morning_price_mean','standard_price_mean','evening_price_mean']]
monthly[['volume','value','morning_volume','evening_volume','standard_volume','off_volume']]=daily.groupby(['year','month']).sum().reset_index(['month','year'])[['volume','value','morning_volume','evening_volume','standard_volume','off_volume']]


monthly
# Out:
#     year  month   day  volume_mean     value_mean  price_weight_mean  \
# 0   2016      1  16.0  3877.909677  216538.697903          57.486909
# 1   2016      2  15.0  3915.110345  263339.799483          67.019849
# 2   2016      3  16.0  3004.254839  192831.319548          63.764714
# 3   2016      4  15.5  1934.450000  119384.364433          59.168072
# 4   2016      5  16.0  1714.970968   95755.502839          51.079876
# ..   ...    ...   ...          ...            ...                ...
# 59  2020     12  16.0  2765.732258  215368.490710          81.531884
# 60  2021      1  16.0  2506.932258  151566.968968          60.267025
# 61  2021      2  14.5  2225.446429  183252.046929          83.585698
# 62  2021      3  16.0  2799.748387  160399.166548          57.899868
# 63  2021      4  15.5  2716.390000  162245.425200          64.228906
#
#     price_mean  off_price_mean  standard_price_mean  morning_price_mean  ...  \
# 0    81.784624       50.482142           100.237891          146.915000  ...
# 1    91.385273       51.665330           102.343821          137.159365  ...
# 2    88.099516       51.887979            98.659245          124.078913  ...
# 3    85.320472       45.608219            97.839609          130.572500  ...
# 4    78.638495       43.121126            99.223370          133.084917  ...
# ..         ...             ...                  ...                 ...  ...
# 59   87.973105       50.377869           107.096349          147.206212  ...
# 60   63.961895       50.870766            79.474182           98.463860  ...
# 61   84.913795       53.185476           111.021325          172.972292  ...
# 62   61.029073       41.411106            72.166095          133.990362  ...
# 63   80.093472       39.906879            91.596735          190.984750  ...
#
#     standard_price_min  off_price_min  morning_price_min  evening_price_min  \
# 0            68.452222      43.144444         113.860000         113.970000
# 1            86.090000      50.480000         110.718000         110.686000
# 2            74.171429      50.518750          95.855000         110.043333
# 3            55.706471       0.000000         105.530000         114.663000
# 4            45.162000      24.316842         106.200000         102.150000
# ..                 ...            ...                ...                ...
# 59           73.705714      45.683750          92.100000         160.030000
# 60           60.162000      44.061818          96.700000          95.067500
# 61           72.030000      43.510417          96.763333         123.676000
# 62           44.221818      25.568000          76.970000         133.610000
# 63           56.354286      30.873750         115.050000         131.640000
#
#     morning_price_stdev    volume        value  morning_volume  \
# 0             12.254047  120215.2  6712699.635           405.6
# 1              7.789197  113538.2  7636854.185          2118.5
# 2             11.776869   93131.9  5977770.906          3143.0
# 3             18.774919   58033.5  3581530.933          1094.6
# 4             22.146905   53164.1  2968420.588           871.7
# ..                  ...       ...          ...             ...
# 59            17.716296   85737.7  6676423.212          6258.0
# 60            18.802658   77714.9  4698576.038          4879.0
# 61            23.101207   62312.5  5131057.314          2446.2
# 62            16.184404   86792.2  4972374.163          3507.4
# 63            24.710161   81491.7  4867362.756          2346.9
#
#     standard_volume  off_volume
# 0           14040.7    103877.5
# 1           25701.0     80348.6
# 2           17821.8     68386.2
# 3           13598.8     42693.7
# 4            6354.3     45201.6
# ..              ...         ...
# 59          20196.2     56545.1
# 60          16883.5     53567.0
# 61          19807.7     36637.8
# 62          31070.4     50069.3
# 63          26604.3     50809.7
#
# [64 rows x 32 columns]

# %%
monthly.to_csv('dam_monthly.csv')
